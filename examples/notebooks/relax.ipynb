# %% [markdown]
# # Relaxation of Structure

# %% [markdown]
# Perform the structure relaxation is also easy with `ASE`_.
# This is one example to relax the force of given structure:

# %%
import os
import pathlib
import numpy as np
# from ase.calculators.interface import Calculator
from ase.lattice.cubic import FaceCenteredCubic
from ase.optimize import BFGS, LBFGS, FIRE
from ase.optimize.sciopt import SciPyFminBFGS, SciPyFminCG
from ase.constraints import StrainFilter, UnitCellFilter
from ase.io.trajectory import Trajectory
from ase import units
import ase.io

from dftpy.config import DefaultOption, OptionFormat
from dftpy.interface import OptimizeDensityConf
from dftpy.api.api4ase import DFTpyCalculator

# %%
############################## initial config ##############################
conf = DefaultOption()
conf['PATH']['pppath'] = '../DATA/'
conf['PP']['Al'] = 'Al_lda.oe01.recpot'
conf['JOB']['calctype'] = 'Energy Force Stress'
conf['KEDF']['kedf'] = 'WT'
conf = OptionFormat(conf)
#-----------------------------------------------------------------------
path = conf['PATH']['pppath']
atoms = ase.io.read(path+'/'+'fcc.vasp')

calc = DFTpyCalculator(config = conf)
atoms.set_calculator(calc)

trajfile = 'opt.traj'
# Out:
# /var/folders/9b/gsh5m3sd3j96rq9k2zstrc_40000gn/T/ipykernel_16442/3153497339.py:13: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)

# %%
af = atoms
af = StrainFilter(atoms)
af = UnitCellFilter(atoms)

opt = SciPyFminCG(af, trajectory = trajfile)

opt.run(fmax = 0.01)

traj = Trajectory(trajfile)
# Out:
#              Step     Time          Energy          fmax
# SciPyFminCG:    0 12:00:24     -227.203397        0.009182
# The final grid size is  [16 16 16]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.349570990503E+00     -8.349571E+00   1.291294E-05    1       1       1.583982E-02
# 1       -8.349571405463E+00     -4.149602E-07   4.432327E-06    1       2       3.421879E-02
# 2       -8.349571591366E+00     -1.859029E-07   3.680967E-06    1       2       5.128694E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.25442118633002836
# Chemical potential (eV)  : 6.923153114003868
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  3.915305506297311E-01
#         II energy (eV): -2.838181551960878E+02
#    KEDF-NL energy (eV): -2.337196353506369E+00
#    KEDF-TF energy (eV):  7.983645831210899E+01
#    KEDF-VW energy (eV):  6.685068194987256E+00
#     PSEUDO energy (eV):  5.661471627619743E+01
#         XC energy (eV): -8.457583749507805E+01
#      TOTAL energy (eV): -2.272034157107488E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.093717096152490
#   kedfs energy (eV)              :             84.184330153589869
#   total energy (a.u.)            :             -8.349571591365937
#   total energy (eV)              :           -227.203415710748828
#   total energy (eV/atom)         :            -56.800853927687207
# Calculate Force...
#               Max force (a.u.) : 0.00000
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00001     -0.00000     -0.00000
#                     -0.00000     -0.00001     -0.00000
#                     -0.00000     -0.00000     -0.00001
#         II stress (a.u.):
#                      0.00702     -0.00000     -0.00000
#                     -0.00000      0.00702     -0.00000
#                     -0.00000     -0.00000      0.00702
#    KEDF-NL stress (a.u.):
#                      0.00012     -0.00000     -0.00000
#                     -0.00000      0.00012     -0.00000
#                     -0.00000     -0.00000      0.00012
#    KEDF-TF stress (a.u.):
#                     -0.00395      0.00000      0.00000
#                      0.00000     -0.00395      0.00000
#                      0.00000      0.00000     -0.00395
#    KEDF-VW stress (a.u.):
#                     -0.00033      0.00000      0.00000
#                      0.00000     -0.00033      0.00000
#                      0.00000      0.00000     -0.00033
#     PSEUDO stress (a.u.):
#                     -0.00475      0.00000      0.00000
#                      0.00000     -0.00475      0.00000
#                      0.00000      0.00000     -0.00475
#         XC stress (a.u.):
#                      0.00190      0.00000      0.00000
#                      0.00000      0.00190      0.00000
#                      0.00000      0.00000      0.00190
#      TOTAL stress (a.u.):
#                     -0.00000      0.00000      0.00000
#                      0.00000     -0.00000      0.00000
#                      0.00000      0.00000     -0.00000
#      TOTAL stress (GPa):
#                     -0.06358      0.00005      0.00015
#                      0.00005     -0.06643      0.00066
#                      0.00015      0.00066     -0.06176
# --------------------------------------------------------------------------------
# The final grid size is  [16 16 16]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.349571746526E+00     -8.349572E+00   4.517426E-06    1       1       2.991533E-02
# /var/folders/9b/gsh5m3sd3j96rq9k2zstrc_40000gn/T/ipykernel_16442/3529303011.py:2: FutureWarning: Import StrainFilter from ase.filters
#   af = StrainFilter(atoms)
# /var/folders/9b/gsh5m3sd3j96rq9k2zstrc_40000gn/T/ipykernel_16442/3529303011.py:3: FutureWarning: Import UnitCellFilter from ase.filters
#   af = UnitCellFilter(atoms)
# 1       -8.349571936006E+00     -1.894807E-07   4.039406E-06    1       3       1.203883E-01
# 2       -8.349572275202E+00     -3.391959E-07   8.157869E-06    1       2       1.254113E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.25428027620289956
# Chemical potential (eV)  : 6.919318754139824
# --------------------------------------------------------------------------------
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  3.917107936259064E-01
#         II energy (eV): -2.837821955347792E+02
#    KEDF-NL energy (eV): -2.337281675966140E+00
#    KEDF-TF energy (eV):  7.981679241882991E+01
#    KEDF-VW energy (eV):  6.685229228295238E+00
#     PSEUDO energy (eV):  5.658861520822920E+01
#         XC energy (eV): -8.456630475712049E+01
#      TOTAL energy (eV): -2.272034343188857E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.092997170220994
#   kedfs energy (eV)              :             84.164739971158994
#   total energy (a.u.)            :             -8.349572275202359
#   total energy (eV)              :           -227.203434318885684
#   total energy (eV/atom)         :            -56.800858579721421
# Calculate Force...
#               Max force (a.u.) : 0.00000
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# Calculate Stress...
#    HARTREE stress (a.u.):
#                     -0.00001     -0.00000     -0.00000
#                     -0.00000     -0.00001     -0.00000
#                     -0.00000     -0.00000     -0.00001
#         II stress (a.u.):
#                      0.00701     -0.00000     -0.00000
#                     -0.00000      0.00701     -0.00000
#                     -0.00000     -0.00000      0.00701
#    KEDF-NL stress (a.u.):
#                      0.00012     -0.00000     -0.00000
#                     -0.00000      0.00012     -0.00000
#                     -0.00000     -0.00000      0.00012
#    KEDF-TF stress (a.u.):
#                     -0.00395      0.00000      0.00000
#                      0.00000     -0.00395      0.00000
#                      0.00000      0.00000     -0.00395
#    KEDF-VW stress (a.u.):
#                     -0.00033      0.00000      0.00000
#                      0.00000     -0.00033      0.00000
#                      0.00000      0.00000     -0.00033
#     PSEUDO stress (a.u.):
#                     -0.00474      0.00000      0.00000
#                      0.00000     -0.00474      0.00000
#                      0.00000      0.00000     -0.00474
#         XC stress (a.u.):
#                      0.00190      0.00000      0.00000
#                      0.00000      0.00190      0.00000
#                      0.00000      0.00000      0.00190
#      TOTAL stress (a.u.):
#                     -0.00000      0.00000      0.00000
#                      0.00000     -0.00000      0.00000
#                      0.00000      0.00000     -0.00000
#      TOTAL stress (GPa):
#                     -0.02875      0.00007      0.00012
#                      0.00007     -0.03124      0.00052
#                      0.00012      0.00052     -0.02704
# --------------------------------------------------------------------------------
# SciPyFminCG:    1 12:00:25     -227.203434        0.003580

# %% [markdown]
# Write the optimize structure in a vasp file

# %%
ase.io.write('opt.vasp', traj[-1], direct = True, vasp5 = True)
